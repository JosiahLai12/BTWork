# %%
import pandas as pd
import requests
import json
import os

import warnings

# Ignore all warnings
warnings.filterwarnings("ignore")

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\josia\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\josia\anaconda3\lib\site-packages (from requests) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\josia\anaconda3\lib\site-packages (from requests) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\josia\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\josia\anaconda3\lib\site-packages (from requests) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
def save_webpage_as_json(url, output_file, folder_name):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check for any request errors
        
        content = response.text  # Get the content of the webpage
        
        # Parse content as JSON
        json_data = json.loads(content)
        
        subfolder_path = os.path.join('stocks', folder_name)
        os.makedirs(subfolder_path, exist_ok=True)
        
        output_path = os.path.join(subfolder_path, output_file)
        # Save JSON data as a dictionary
        with open(output_path, 'w', encoding='utf-8') as json_file:
            json.dump(json_data, json_file, indent=4)
        
        print(f"Webpage content saved as {output_file}")
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")

# %%
asx_codes = {"Ticker": ["CSL", "ABX", "A2B", "ASK", "ABC", "ALU", "CAR", "CBA", 'CTD', 'DRR', 'DXS', 'DHG', 'DMP', 'DOW', 'APE', 'FMG', 'GOR', 'GMD']}
asx_df = pd.DataFrame(asx_codes)

# %%
shz_codes = {"Ticker":["000001", "000002","000004","000005","000006","000007","000008","000009","000010",]}
shz_df = pd.DataFrame(shz_codes)

# %%
def my_function(exchange, stock_list, exchange_code_official):
    final_df = pd.DataFrame()
    for i in stock_list['Ticker']:
        string_start = "https://eodhistoricaldata.com/api/fundamentals/"
        string_end = "?api_token=64e6bb917d6ca7.00493420"
        url_string = string_start + i + "." + exchange + string_end
       
        output_filename = i + "_" + exchange + ".json"

        save_webpage_as_json(url_string, output_filename, exchange_code_official)
        
        file_path = 'stocks/'+ exchange_code_official +"/"+output_filename
        raw_data = open(file_path)
        dict_data = json.load(raw_data)
   
        new_dict = {'Code':dict_data['General']['Code'], 'Exchange':exchange_code_official, 'Name':dict_data['General']['Name'],'GicSector':dict_data['General']['GicSector'],
                   'GicGroup':dict_data['General']['GicGroup'],'GicIndustry':dict_data['General']['GicIndustry'],'GicSubIndustry':dict_data['General']['GicSubIndustry']}
    
        final_df = final_df.append(new_dict, ignore_index = True)
        
    return final_df

# %%
asx = my_function("AU", asx_df, "ASX")
# Out:
# Webpage content saved as CSL_AU.json
# Webpage content saved as ABX_AU.json
# Webpage content saved as A2B_AU.json
# Webpage content saved as ASK_AU.json
# Webpage content saved as ABC_AU.json
# Webpage content saved as ALU_AU.json
# Webpage content saved as CAR_AU.json
# Webpage content saved as CBA_AU.json
# Webpage content saved as CTD_AU.json
# Webpage content saved as DRR_AU.json
# Webpage content saved as DXS_AU.json
# Webpage content saved as DHG_AU.json
# Webpage content saved as DMP_AU.json
# Webpage content saved as DOW_AU.json
# Webpage content saved as APE_AU.json
# Webpage content saved as FMG_AU.json
# Webpage content saved as GOR_AU.json
# Webpage content saved as GMD_AU.json

# %%
shz = my_function("SHE", shz_df, "SHZ")
# Out:
# Webpage content saved as 000001_SHE.json
# Webpage content saved as 000002_SHE.json
# Webpage content saved as 000004_SHE.json
# Webpage content saved as 000005_SHE.json
# Webpage content saved as 000006_SHE.json
# Webpage content saved as 000007_SHE.json
# Webpage content saved as 000008_SHE.json
# Webpage content saved as 000009_SHE.json
# Webpage content saved as 000010_SHE.json

# %%
asx
# Out:
#    Code Exchange                            Name               GicSector  \
# 0   CSL      ASX                         CSL Ltd             Health Care
# 1   ABX      ASX                   ABx Group Ltd               Materials
# 2   A2B      ASX               A2B Australia Ltd  Information Technology
# 3   ASK      ASX             ABACUS STORAGE KING                  Energy
# 4   ABC      ASX                       Adbri Ltd               Materials
# 5   ALU      ASX                      Altium Ltd  Information Technology
# 6   CAR      ASX                Carsales.Com Ltd  Communication Services
# 7   CBA      ASX  Commonwealth Bank Of Australia              Financials
# 8   CTD      ASX  Corporate Travel Managment Ltd  Consumer Discretionary
# 9   DRR      ASX           Deterra Royalties Ltd               Materials
# 10  DXS      ASX                           Dexus             Real Estate
# 11  DHG      ASX   Domain Holdings Australia Ltd  Communication Services
# 12  DMP      ASX  Domino'S Pizza Enterprises Ltd  Consumer Discretionary
# 13  DOW      ASX                  Downer Edi Ltd             Industrials
# 14  APE      ASX                   AP Eagers Ltd  Consumer Discretionary
# 15  FMG      ASX      Fortescue Metals Group Ltd               Materials
# 16  GOR      ASX         Gold Road Resources Ltd               Materials
# 17  GMD      ASX            Genesis Minerals Ltd               Materials
#
#                                           GicGroup  \
# 0   Pharmaceuticals, Biotechnology & Life Sciences
# 1                                        Materials
# 2                              Software & Services
# 3                                           Energy
# 4                                        Materials
# 5                              Software & Services
# 6                            Media & Entertainment
# 7                                            Banks
# 8                                Consumer Services
# 9                                        Materials
# 10    Equity Real Estate Investment Trusts (REITs)
# 11                           Media & Entertainment
# 12                               Consumer Services
# 13              Commercial & Professional Services
# 14    Consumer Discretionary Distribution & Retail
# 15                                       Materials
# 16                                       Materials
# 17                                       Materials
#
#                        GicIndustry                  GicSubIndustry
# 0                    Biotechnology                   Biotechnology
# 1                  Metals & Mining                        Aluminum
# 2                         Software            Application Software
# 3      Oil, Gas & Consumable Fuels         Coal & Consumable Fuels
# 4           Construction Materials          Construction Materials
# 5                         Software            Application Software
# 6     Interactive Media & Services    Interactive Media & Services
# 7                            Banks               Diversified Banks
# 8    Hotels, Restaurants & Leisure  Hotels, Resorts & Cruise Lines
# 9                  Metals & Mining     Diversified Metals & Mining
# 10               Diversified REITs                    Office REITs
# 11    Interactive Media & Services    Interactive Media & Services
# 12   Hotels, Restaurants & Leisure                     Restaurants
# 13  Commercial Services & Supplies    Diversified Support Services
# 14                Specialty Retail               Automotive Retail
# 15                 Metals & Mining                           Steel
# 16                 Metals & Mining                            Gold
# 17                 Metals & Mining     Diversified Metals & Mining
