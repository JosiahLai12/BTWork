# %%
import pandas as pd

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in c:\users\josia\anaconda3\lib\site-packages (2.31.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\josia\anaconda3\lib\site-packages (from requests) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\josia\anaconda3\lib\site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\josia\anaconda3\lib\site-packages (from requests) (1.26.14)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\josia\anaconda3\lib\site-packages (from requests) (2.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json

def save_webpage_as_json(url, output_file):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Check for any request errors
        
        content = response.text  # Get the content of the webpage
        
        # Parse content as JSON
        json_data = json.loads(content)
        
        # Save JSON data as a dictionary
        with open(output_file, 'w', encoding='utf-8') as json_file:
            json.dump(json_data, json_file, indent=4)
        
        print(f"Webpage content saved as {output_file}")
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")

# Provide the URL and output filename
webpage_url = "https://eodhistoricaldata.com/api/fundamentals/NVDA.US?api_token=64e6bb917d6ca7.00493420"  # Replace with your webpage URL
output_filename = "NVDA.json"

save_webpage_as_json(webpage_url, output_filename)
# Out:
# Webpage content saved as NVDA.json

# %%
nvda = open('NVDA.json')

# %%
NVDA = json.load(nvda)

# %%
nvda_df = pd.DataFrame.from_dict(NVDA['General'])
nvda_df.drop(columns=nvda_df.columns[-8:], axis=1, inplace=True)
#new.head()

# %%
def pref_column(df):
    new_df = df[['Code', 'Exchange', 'Name', 'GicSector', 'GicGroup', 'GicIndustry', 'GicSubIndustry']]
    return new_df

# %%
NVDA_df = pref_column(nvda_df)

# %%
NVDA_df
# Out:
#          Code Exchange                Name               GicSector  \
# Street   NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# City     NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# State    NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# Country  NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# ZIP      NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# 0        NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# 1        NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# 2        NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# 3        NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# 4        NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# 5        NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# 6        NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# 7        NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# 8        NVDA   NASDAQ  NVIDIA Corporation  Information Technology
# 9        NVDA   NASDAQ  NVIDIA Corporation  Information Technology
#
#                                          GicGroup  \
# Street   Semiconductors & Semiconductor Equipment
# City     Semiconductors & Semiconductor Equipment
# State    Semiconductors & Semiconductor Equipment
# Country  Semiconductors & Semiconductor Equipment
# ZIP      Semiconductors & Semiconductor Equipment
# 0        Semiconductors & Semiconductor Equipment
# 1        Semiconductors & Semiconductor Equipment
# 2        Semiconductors & Semiconductor Equipment
# 3        Semiconductors & Semiconductor Equipment
# 4        Semiconductors & Semiconductor Equipment
# 5        Semiconductors & Semiconductor Equipment
# 6        Semiconductors & Semiconductor Equipment
# 7        Semiconductors & Semiconductor Equipment
# 8        Semiconductors & Semiconductor Equipment
# 9        Semiconductors & Semiconductor Equipment
#
#                                       GicIndustry  GicSubIndustry
# Street   Semiconductors & Semiconductor Equipment  Semiconductors
# City     Semiconductors & Semiconductor Equipment  Semiconductors
# State    Semiconductors & Semiconductor Equipment  Semiconductors
# Country  Semiconductors & Semiconductor Equipment  Semiconductors
# ZIP      Semiconductors & Semiconductor Equipment  Semiconductors
# 0        Semiconductors & Semiconductor Equipment  Semiconductors
