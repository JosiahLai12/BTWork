# %%
import json
import pandas as pd

# %%
dat = open('BTtesting/data/000001SHZ.json')

# %%
data = json.load(dat)

# %%
data['General']['GicSubIndustry']
# Out:
# 'Diversified Banks'

# %%
new = pd.DataFrame.from_dict(data['General'])

# %%
new.drop(columns=new.columns[-8:], axis=1, inplace=True)
#new.head()

# %%
nvda = open('BTtesting/data/NVDAUS.json')
NVDA = json.load(nvda)

# %%
nvda_df = pd.DataFrame.from_dict(NVDA['General'])
nvda_df.drop(columns=nvda_df.columns[-8:], axis=1, inplace=True)

# %%
nvda_df
# Out:
#          Code          Type                Name Exchange CurrencyCode  \
# Street   NVDA  Common Stock  NVIDIA Corporation   NASDAQ          USD
# City     NVDA  Common Stock  NVIDIA Corporation   NASDAQ          USD
# State    NVDA  Common Stock  NVIDIA Corporation   NASDAQ          USD
# Country  NVDA  Common Stock  NVIDIA Corporation   NASDAQ          USD
# ZIP      NVDA  Common Stock  NVIDIA Corporation   NASDAQ          USD
# 0        NVDA  Common Stock  NVIDIA Corporation   NASDAQ          USD
# 1        NVDA  Common Stock  NVIDIA Corporation   NASDAQ          USD
# 2        NVDA  Common Stock  NVIDIA Corporation   NASDAQ          USD
# 3        NVDA  Common Stock  NVIDIA Corporation   NASDAQ          USD
# 4        NVDA  Common Stock  NVIDIA Corporation   NASDAQ          USD
# 5        NVDA  Common Stock  NVIDIA Corporation   NASDAQ          USD
# 6        NVDA  Common Stock  NVIDIA Corporation   NASDAQ          USD
# ...
